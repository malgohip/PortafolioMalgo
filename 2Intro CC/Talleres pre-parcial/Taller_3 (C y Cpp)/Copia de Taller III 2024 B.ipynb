# %% [markdown]
# **TALLER III**
#
# **PROGRAMACIÓN EN C O C++**
#
# **Fecha Parcial: 4 de junio 2024**
#
# Tenga en cuenta las siguientes instrucciones:
#
# * Solo se permiten los comandos enseñados en clase y presentes en las notas de clase que se compartieron con los y las estudiantes.
#
# * El ingreso de datos al algoritmo debe ser claro, simple y amigable con el usuario. Si no hay claridad en el formato de los datos de ingreso la nota cera cero en el ejercicio.
#
# * En cada ejercicio debe mostrarse los datos de entrada y los resultados que reporta el algoritmo; si esta información no está presente, se evaluará con cero el punto.
#
# * Todos  los códigos deben presentarse en C o C++.

# %% [markdown]
#  # Ejercicio 1.
#
#  Determine la codificación binaria con 64 bits en el formato de la IEEE para los números 5/6 y 1051. Indique claramente los bits para signo, exponente y mantisa en cada caso. Especifique si los números dados son números de máquina y justifique su respuesta. El ejercicio debe realizarse sin uso de ayudas computacionales (calculadora,  computador etc). Deje todos sus computos sobre la hoja de respuesta, no presente valores aproximados, si las operaciones implican periodicidad en los resultados indíquelo.

# %% [markdown]
# # Ejercicio 2
#
# Diseñe un código que calcule los dos valores más grandes presentes un vector de valores numéricos. El vector debe tener un diseñó dinámico, es decir debe usar la memoría exacta para la cantidad de datos que indique el usuario. Todas las funciones del algoritmo deben administrar todos sus argumentos por referencia. Su algoritmo debe contar de las siguiente funciones:
# * Lectura de vectores
# * Escritura de vectores.
# * Intercambio de valores.
# * Ordenamiento de valores.
# Use como referencia el ejercicio 3 de la sección 5.1 de las notas de clase.

# %% [markdown]
# # Ejercicio 3.
#
# Diseñe un código que permita determinar, si un par de segmentos de recta AB y CD sobre un plano se traslapan, se cortan en un punto o no se intersectan. El usuario da las coordenadas de los puntos extremos A, B, C y D al código. Si los segmentos se traslapan o se cortan, debe indicarse las coordenadas de los extremos del traslaopo o las coordenadas del punto de corte.

# %% [markdown]
# # Ejercicio 4.
# Diseñe un código en C que permita determinar el número de máquina más próximo pero mayor que 550  en formato double. El código debe indicar el resultado como una potencia de 2 y en notación científica.

# %% [markdown]
# |

# %% [markdown]
# # Ejercicio 6.
#
# Usando los comandos de administración de string, diseñe un código que permita construir un string que contenga las palabras de dos string dados por el usuario pero ordenadas mediante el orden lexicogràfico. Los string dados por el usuario podrian ser longitud diferente. Algoritmo debe presentar los string dados por el usuario y el string construido.

# %% [markdown]
# # Ejercicio 7
#
# Presente un código que use  `struct()` para administrar números complejos. El algoritmo debe permitirle al usuario ingresar un par de números complejos y efectuar una de las operaciones aritméticas entre: suma, resta, multiplicación o división. El algoritmo debe ofrecer un menú para las operaciones aritméticas y estas deben manejar todos sus argumentos por referencia.
